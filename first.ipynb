# %%
# !pip install ipywidgets
# !pip install langchain==0.0.208 deeplake openai tiktoken
# !pip install langchain
# !pip install langchain==0.0.208 deeplake openai tiktoken
# !pip install deeplake openai tiktoken
# !pip install deeplake
# !pip3 install google-api-python-client
# !pip3 install pip install google-api-core
# !pip install --upgrade google-api-python-client
# !pip install gpt4all==0.2.3
# !pip install -q huggingface_hub
# !pip install transformers
# !pip install pypdf
# !pip install python-dotenv
# !pip install sentencepiece
# !pip install pyllamacpp
# !pip install pyvis
# !pip install pyOpenSSL
# !pip install -q unstructured selenium
# !conda update -n base -c conda-forge conda
# !pip install -U pyopenssl cryptography
# !pip install -U jinja2
# !pip install -U MarkupSafe 
# !pip install -U spacy
# !pip install numpy scipy scikit-learn
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: ipywidgets in /home/sharath/.local/lib/python3.10/site-packages (8.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/sharath/.local/lib/python3.10/site-packages (from ipywidgets) (6.24.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/sharath/.local/lib/python3.10/site-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/sharath/.local/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/sharath/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/sharath/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: comm>=0.1.1 in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.1)
# Requirement already satisfied: psutil in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /home/sharath/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.2)
# Requirement already satisfied: backcall in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/sharath/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sharath/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/sharath/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.9.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sharath/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/sharath/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/sharath/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /home/sharath/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: langchain in /home/sharath/.local/lib/python3.10/site-packages (0.0.208)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (2.0.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (0.5.13)
# Requirement already satisfied: langchainplus-sdk>=0.0.13 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (0.0.20)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (1.25.1)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (1.10.11)
# Requirement already satisfied: requests<3,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/sharath/.local/lib/python3.10/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/sharath/.local/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/sharath/.local/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/sharath/.local/lib/python3.10/site-packages (from pydantic<2,>=1->langchain) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /home/sharath/.local/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/sharath/.local/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: deeplake in /home/sharath/.local/lib/python3.10/site-packages (3.6.12)
# Requirement already satisfied: openai in /home/sharath/.local/lib/python3.10/site-packages (0.27.8)
# Requirement already satisfied: tiktoken in /home/sharath/.local/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: numpy in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (1.25.1)
# Requirement already satisfied: pillow in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from deeplake) (10.0.0)
# Requirement already satisfied: boto3 in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (1.26.76)
# Requirement already satisfied: click in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from deeplake) (8.1.6)
# Requirement already satisfied: pathos in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (0.3.0)
# Requirement already satisfied: humbug>=0.3.1 in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (0.3.2)
# Requirement already satisfied: tqdm in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (4.65.0)
# Requirement already satisfied: numcodecs in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (0.11.0)
# Requirement already satisfied: pyjwt in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from deeplake) (2.8.0)
# Requirement already satisfied: aioboto3>=10.4.0 in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (11.2.0)
# Requirement already satisfied: nest-asyncio in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (1.5.6)
# Requirement already satisfied: requests>=2.20 in /home/sharath/.local/lib/python3.10/site-packages (from openai) (2.31.0)
# Requirement already satisfied: aiohttp in /home/sharath/.local/lib/python3.10/site-packages (from openai) (3.8.5)
# Requirement already satisfied: regex>=2022.1.18 in /home/sharath/.local/lib/python3.10/site-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: aiobotocore[boto3]==2.5.0 in /home/sharath/.local/lib/python3.10/site-packages (from aioboto3>=10.4.0->deeplake) (2.5.0)
# Requirement already satisfied: botocore<1.29.77,>=1.29.76 in /home/sharath/.local/lib/python3.10/site-packages (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.29.76)
# Requirement already satisfied: wrapt>=1.10.10 in /home/sharath/.local/lib/python3.10/site-packages (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.15.0)
# Requirement already satisfied: aioitertools>=0.5.1 in /home/sharath/.local/lib/python3.10/site-packages (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (0.11.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp->openai) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from boto3->deeplake) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/sharath/.local/lib/python3.10/site-packages (from boto3->deeplake) (0.6.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: entrypoints in /home/sharath/.local/lib/python3.10/site-packages (from numcodecs->deeplake) (0.4)
# Requirement already satisfied: ppft>=1.7.6.6 in /home/sharath/.local/lib/python3.10/site-packages (from pathos->deeplake) (1.7.6.6)
# Requirement already satisfied: dill>=0.3.6 in /home/sharath/.local/lib/python3.10/site-packages (from pathos->deeplake) (0.3.6)
# Requirement already satisfied: pox>=0.3.2 in /home/sharath/.local/lib/python3.10/site-packages (from pathos->deeplake) (0.3.2)
# Requirement already satisfied: multiprocess>=0.70.14 in /home/sharath/.local/lib/python3.10/site-packages (from pathos->deeplake) (0.70.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sharath/.local/lib/python3.10/site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.29.77,>=1.29.76->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.16.0)
# Requirement already satisfied: deeplake in /home/sharath/.local/lib/python3.10/site-packages (3.6.12)
# Requirement already satisfied: numpy in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (1.25.1)
# Requirement already satisfied: pillow in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from deeplake) (10.0.0)
# Requirement already satisfied: boto3 in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (1.26.76)
# Requirement already satisfied: click in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from deeplake) (8.1.6)
# Requirement already satisfied: pathos in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (0.3.0)
# Requirement already satisfied: humbug>=0.3.1 in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (0.3.2)
# Requirement already satisfied: tqdm in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (4.65.0)
# Requirement already satisfied: numcodecs in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (0.11.0)
# Requirement already satisfied: pyjwt in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from deeplake) (2.8.0)
# Requirement already satisfied: aioboto3>=10.4.0 in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (11.2.0)
# Requirement already satisfied: nest-asyncio in /home/sharath/.local/lib/python3.10/site-packages (from deeplake) (1.5.6)
# Requirement already satisfied: aiobotocore[boto3]==2.5.0 in /home/sharath/.local/lib/python3.10/site-packages (from aioboto3>=10.4.0->deeplake) (2.5.0)
# Requirement already satisfied: botocore<1.29.77,>=1.29.76 in /home/sharath/.local/lib/python3.10/site-packages (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.29.76)
# Requirement already satisfied: aiohttp>=3.3.1 in /home/sharath/.local/lib/python3.10/site-packages (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (3.8.5)
# Requirement already satisfied: wrapt>=1.10.10 in /home/sharath/.local/lib/python3.10/site-packages (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.15.0)
# Requirement already satisfied: aioitertools>=0.5.1 in /home/sharath/.local/lib/python3.10/site-packages (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (0.11.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from boto3->deeplake) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/sharath/.local/lib/python3.10/site-packages (from boto3->deeplake) (0.6.1)
# Requirement already satisfied: requests in /home/sharath/.local/lib/python3.10/site-packages (from humbug>=0.3.1->deeplake) (2.31.0)
# Requirement already satisfied: entrypoints in /home/sharath/.local/lib/python3.10/site-packages (from numcodecs->deeplake) (0.4)
# Requirement already satisfied: ppft>=1.7.6.6 in /home/sharath/.local/lib/python3.10/site-packages (from pathos->deeplake) (1.7.6.6)
# Requirement already satisfied: dill>=0.3.6 in /home/sharath/.local/lib/python3.10/site-packages (from pathos->deeplake) (0.3.6)
# Requirement already satisfied: pox>=0.3.2 in /home/sharath/.local/lib/python3.10/site-packages (from pathos->deeplake) (0.3.2)
# Requirement already satisfied: multiprocess>=0.70.14 in /home/sharath/.local/lib/python3.10/site-packages (from pathos->deeplake) (0.70.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sharath/.local/lib/python3.10/site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from requests->humbug>=0.3.1->deeplake) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->humbug>=0.3.1->deeplake) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests->humbug>=0.3.1->deeplake) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sharath/.local/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.3.1)
# Requirement already satisfied: six>=1.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.29.77,>=1.29.76->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.16.0)
# Requirement already satisfied: google-api-python-client in /home/sharath/.local/lib/python3.10/site-packages (2.94.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-python-client) (2.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.59.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.23.4)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.26.16)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Requirement already satisfied: pip in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (23.2.1)
# Requirement already satisfied: install in /home/sharath/.local/lib/python3.10/site-packages (1.3.5)
# Requirement already satisfied: google-api-core in /home/sharath/.local/lib/python3.10/site-packages (2.11.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core) (1.59.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core) (4.23.4)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core) (2.22.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core) (2023.7.22)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core) (0.5.0)
# Requirement already satisfied: google-api-python-client in /home/sharath/.local/lib/python3.10/site-packages (2.94.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-python-client) (2.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.59.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.23.4)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sharath/.local/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.26.16)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Requirement already satisfied: gpt4all==0.2.3 in /home/sharath/.local/lib/python3.10/site-packages (0.2.3)
# Requirement already satisfied: requests in /home/sharath/.local/lib/python3.10/site-packages (from gpt4all==0.2.3) (2.31.0)
# Requirement already satisfied: tqdm in /home/sharath/.local/lib/python3.10/site-packages (from gpt4all==0.2.3) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from requests->gpt4all==0.2.3) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->gpt4all==0.2.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->gpt4all==0.2.3) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests->gpt4all==0.2.3) (2023.7.22)
# Requirement already satisfied: transformers in /home/sharath/.local/lib/python3.10/site-packages (4.31.0)
# Requirement already satisfied: filelock in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /home/sharath/.local/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /home/sharath/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sharath/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: pypdf in /home/sharath/.local/lib/python3.10/site-packages (3.12.2)
# Requirement already satisfied: python-dotenv in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: sentencepiece in /home/sharath/.local/lib/python3.10/site-packages (0.1.99)
# Requirement already satisfied: pyllamacpp in /home/sharath/.local/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: pyvis in /home/sharath/.local/lib/python3.10/site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /home/sharath/.local/lib/python3.10/site-packages (from pyvis) (8.14.0)
# Requirement already satisfied: jinja2>=2.9.6 in /home/sharath/.local/lib/python3.10/site-packages (from pyvis) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /home/sharath/.local/lib/python3.10/site-packages (from pyvis) (3.0.1)
# Requirement already satisfied: networkx>=1.11 in /home/sharath/.local/lib/python3.10/site-packages (from pyvis) (3.1)
# Requirement already satisfied: backcall in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: stack-data in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /home/sharath/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sharath/.local/lib/python3.10/site-packages (from jinja2>=2.9.6->pyvis) (2.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/sharath/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sharath/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/sharath/.local/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/sharath/.local/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: pure-eval in /home/sharath/.local/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Requirement already satisfied: pyOpenSSL in /home/sharath/.local/lib/python3.10/site-packages (23.2.0)
# Requirement already satisfied: cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 in /home/sharath/.local/lib/python3.10/site-packages (from pyOpenSSL) (41.0.2)
# Requirement already satisfied: cffi>=1.12 in /home/sharath/.local/lib/python3.10/site-packages (from cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL) (1.15.1)
# Requirement already satisfied: pycparser in /home/sharath/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL) (2.21)
# Requirement already satisfied: pyopenssl in /home/sharath/.local/lib/python3.10/site-packages (23.2.0)
# Requirement already satisfied: cryptography in /home/sharath/.local/lib/python3.10/site-packages (41.0.2)
# Requirement already satisfied: cffi>=1.12 in /home/sharath/.local/lib/python3.10/site-packages (from cryptography) (1.15.1)
# Requirement already satisfied: pycparser in /home/sharath/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography) (2.21)
# Requirement already satisfied: jinja2 in /home/sharath/.local/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sharath/.local/lib/python3.10/site-packages (from jinja2) (2.1.3)
# Requirement already satisfied: MarkupSafe in /home/sharath/.local/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: spacy in /home/sharath/.local/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (1.25.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (1.10.11)
# Requirement already satisfied: jinja2 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/sharath/.local/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/sharath/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/sharath/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/sharath/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sharath/.local/lib/python3.10/site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: numpy in /home/sharath/.local/lib/python3.10/site-packages (1.25.1)
# Requirement already satisfied: scipy in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (1.11.1)
# Requirement already satisfied: scikit-learn in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/sharath/.local/lib/python3.10/site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /home/sharath/.local/lib/python3.10/site-packages (from sentence_transformers) (4.31.0)
# Requirement already satisfied: tqdm in /home/sharath/.local/lib/python3.10/site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /home/sharath/.local/lib/python3.10/site-packages (from sentence_transformers) (2.0.1)
# Collecting torchvision (from sentence_transformers)
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 7.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/sharath/.local/lib/python3.10/site-packages (from sentence_transformers) (1.25.1)
# Requirement already satisfied: scikit-learn in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from sentence_transformers) (1.3.0)
# Requirement already satisfied: scipy in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from sentence_transformers) (1.11.1)
# Requirement already satisfied: nltk in /home/sharath/.local/lib/python3.10/site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /home/sharath/.local/lib/python3.10/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /home/sharath/.local/lib/python3.10/site-packages (from sentence_transformers) (0.16.4)
# Requirement already satisfied: filelock in /home/sharath/.local/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /home/sharath/.local/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /home/sharath/.local/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sharath/.local/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /home/sharath/.local/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/sharath/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: setuptools in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (68.0.0)
# Requirement already satisfied: wheel in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (0.41.0)
# Requirement already satisfied: cmake in /home/sharath/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.27.0)
# Requirement already satisfied: lit in /home/sharath/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /home/sharath/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/sharath/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/sharath/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.1)
# Requirement already satisfied: click in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from nltk->sentence_transformers) (8.1.6)
# Requirement already satisfied: joblib in /home/sharath/.local/lib/python3.10/site-packages (from nltk->sentence_transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from torchvision->sentence_transformers) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sharath/.local/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sharath/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sharath/anaconda3/envs/py310/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sharath/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /home/sharath/.local/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=1097cc8bee7424c8627de4dab2465256c857cac4d3b805f0fe65b6a43d6a6447
#   Stored in directory: /home/sharath/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: torchvision, sentence_transformers
# Successfully installed sentence_transformers-2.2.2 torchvision-0.15.2

# %%
import os
from os.path import join, dirname
from dotenv import load_dotenv
from setuptools import setup

from pathlib import Path

cwd = Path().resolve()
# or this
cwd = Path.cwd()

# dotenv_path = join(dirname(__file__), '.env')
# print(dotenv_path)

load_dotenv()

OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
ACTIVELOOP_TOKEN = os.environ.get("ACTIVELOOP_TOKEN")
GOOGLE_API_KEY=os.environ.get("GOOGLE_API_KEY")
GOOGLE_CSE_ID=os.environ.get("GOOGLE_CSE_ID")
HUGGINGFACEHUB_API_TOKEN=os.environ.get("HUGGINGFACEHUB_API_TOKEN")
ELEVEN_API_KEY=os.environ.get("ELEVEN_API_KEY")
# print(ACTIVELOOP_TOKEN)

# %%
from langchain.llms import OpenAI
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
llm = OpenAI(model="text-davinci-003", temperature=0.9)
text = "Suggest a personalized workout routine for someone looking to improve cardiovascular endurance and prefers outdoor activities."
print(llm(text))

# %%
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI
from langchain.chains import LLMChain

llm = OpenAI(model="text-davinci-003", temperature=0.9)
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?",
)

chain = LLMChain(llm=llm, prompt=prompt)

# Run the chain only specifying the input variable.
print(chain.run("eco-friendly water bottles"))

# %%
from langchain.llms import OpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory

llm = OpenAI(model="text-davinci-003", temperature=0)
conversation = ConversationChain(
    llm=llm,
    verbose=True,
    memory=ConversationBufferMemory()
)

# Start the conversation
conversation.predict(input="Tell me about yourself.")

# Continue the conversation
conversation.predict(input="What can you do?")
conversation.predict(input="How can you help me with data analysis?")

# Display the conversation
print(conversation)

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import DeepLake
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA

# Before executing the following code, make sure to have your
# Activeloop key saved in the “ACTIVELOOP_TOKEN” environment variable.

# instantiate the LLM and embeddings models
llm = OpenAI(model="text-davinci-003", temperature=0)
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")

# create our documents
texts = [
    "Napoleon Bonaparte was born in 15 August 1769",
    "Louis XIV was born in 5 September 1638"
]
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.create_documents(texts)

# create Deep Lake dataset
# TODO: use your organization id here. (by default, org id is your username)
my_activeloop_org_id = "sharathshetty" 
my_activeloop_dataset_name = "langchain_course_from_zero_to_hero"
dataset_path = f"hub://{my_activeloop_org_id}/{my_activeloop_dataset_name}"
db = DeepLake(dataset_path=dataset_path, embedding_function=embeddings)

# add documents to our Deep Lake dataset
db.add_documents(docs)

# %%
retrieval_qa = RetrievalQA.from_chain_type(
	llm=llm,
	chain_type="stuff",
	retriever=db.as_retriever()
)

# %%
from langchain.agents import initialize_agent, Tool
from langchain.agents import AgentType

tools = [
    Tool(
        name="Retrieval QA System",
        func=retrieval_qa.run,
        description="Useful for answering questions."
    ),
]

agent = initialize_agent(
	tools,
	llm,
	agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
	verbose=True
)

# %%
response = agent.run("When was Napoleone born?")
print(response)

# %%
# load the existing Deep Lake dataset and specify the embedding function
db = DeepLake(dataset_path=dataset_path, embedding_function=embeddings)

# create new documents
texts = [
    "Lady Gaga was born in 28 March 1986",
    "Michael Jeffrey Jordan was born in 17 February 1963"
]
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.create_documents(texts)

# add documents to our Deep Lake dataset
db.add_documents(docs)

# %%
# instantiate the wrapper class for GPT3
llm = OpenAI(model="text-davinci-003", temperature=0)

# create a retriever from the db
retrieval_qa = RetrievalQA.from_chain_type(
	llm=llm, chain_type="stuff", retriever=db.as_retriever()
)

# instantiate a tool that uses the retriever
tools = [
    Tool(
        name="Retrieval QA System",
        func=retrieval_qa.run,
        description="Useful for answering questions."
    ),
]

# create an agent that uses the tool
agent = initialize_agent(
	tools,
	llm,
	agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
	verbose=True
)

# %%
response = agent.run("When was Michael Jordan born?")
print(response)

# %%
from langchain.llms import OpenAI

from langchain.agents import AgentType
from langchain.agents import load_tools
from langchain.agents import initialize_agent

from langchain.agents import Tool
from langchain.utilities import GoogleSearchAPIWrapper
llm = OpenAI(model="text-davinci-003", temperature=0)

search = GoogleSearchAPIWrapper()

tools = [
    Tool(
        name = "google-search",
        func=search.run,
        description="useful for when you need to search google to answer questions about current events"
    )
]
agent = initialize_agent(tools, 
                         llm, 
                         agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION, 
                         verbose=True,
                         max_iterations=6)

response = agent("What's the latest news about the Mars rover?")
print(response['output'])
# Out:
# > Entering new  chain...
#  I need to find out the latest news about the Mars rover
# Action: google-search
# Action Input: "latest news Mars rover"
# Observation: The mission has concluded that the solar-powered lander has run out of energy after more than four years on the Red Planet. Dec 15, 2021 ... Mars Sample Return is going to have great stuff to choose from!” Get the Latest JPL News. SUBSCRIBE TO THE NEWSLETTER. NASA's Curiosity rover is discovering odd rocks halfway into a region called the "clay-bearing unit." ... This panorama of a location called "Teal Ridge" was ... Aug 5, 2022 ... NASA's Curiosity Mars rover set out to answer a big question when it ... an update on the rover's capabilities a decade after landing in ... Curiosity rover finds water-carved 'book' rock on Mars (photo) ... A book-shaped rock on Mars was likely carved by ancient water running through the area, ... Apr 25, 2023 ... China's Mars rover, which has been in longer-than-expected hibernation on the red planet since May 2022, has likely suffered excessive ... Nasa rover spots bizarre donut shaped rock on Mars · <p>Nasa's simulated Mars habitat includes a sandbox to simulate the Martian landscape<. Mar 7, 2023 ... 27, helps provide scientists with information about the particle sizes within the clouds. Sign up for National Breaking News Alerts. Apr 28, 2023 ... Friday's news comes days after mission leaders acknowledged that the Zhurong rover has yet to wake up since going into hibernation for the ... Curiosity Rover · Nasa's Curiosity Mars rover can provide a lot of information about the Red Planet, but · An image taken by the Nasa Spirit rover, which shows ...
# Thought: I now know the final answer
# Final Answer: The latest news about the Mars rover is that the mission has concluded that the solar-powered lander has run out of energy after more than four years on the Red Planet. China's Mars rover has likely suffered excessive damage due to hibernation, and the Curiosity rover has spotted a bizarre donut-shaped rock on Mars. Additionally, the Spirit rover has taken an image of the Martian landscape.
#
# > Finished chain.
# The latest news about the Mars rover is that the mission has concluded that the solar-powered lander has run out of energy after more than four years on the Red Planet. China's Mars rover has likely suffered excessive damage due to hibernation, and the Curiosity rover has spotted a bizarre donut-shaped rock on Mars. Additionally, the Spirit rover has taken an image of the Martian landscape.
